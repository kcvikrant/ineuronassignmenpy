# %%
import pandas as pd 
import numpy as np

df = pd.DataFrame({'From_To':['LoNDon_paris','MAdrid_miLAN','londON_StockOlm',
                              'Budapest_PaRis','Brussels_londOn'],
                   'FlightNumber':[10045,np.nan,10065,np.nan,10085],
                   
                  'RecentDelays':[[23,47],[],[24,43,87],[13],[67,32]],
                   
                  'Airline':['KLM(!)','<Air France> (12)','(British Airways. )',
                            '12. Air France',"Swiss Air"]})

# %%
df
# Out:
#            From_To  FlightNumber  RecentDelays              Airline
# 0     LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1     MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3   Budapest_PaRis           NaN          [13]       12. Air France
# 4  Brussels_londOn       10085.0      [67, 32]            Swiss Air

# %%
##filling na values AND convert flot into int column
df['FlightNumber'] = df['FlightNumber'].interpolate()
df['FlightNumber'] = df['FlightNumber'].astype(int)

# %%
df['FlightNumber']
# Out:
# 0    10045
# 1    10055
# 2    10065
# 3    10075
# 4    10085
# Name: FlightNumber, dtype: int32

# %%
##2
temp_df = df.copy()

# %%
temp_df[['From','To']] = temp_df.From_To.str.split("_",expand=True)
temp_df
# Out:
#            From_To  FlightNumber  RecentDelays              Airline      From  \
# 0     LoNDon_paris         10045      [23, 47]               KLM(!)    LoNDon
# 1     MAdrid_miLAN         10055            []    <Air France> (12)    MAdrid
# 2  londON_StockOlm         10065  [24, 43, 87]  (British Airways. )    londON
# 3   Budapest_PaRis         10075          [13]       12. Air France  Budapest
# 4  Brussels_londOn         10085      [67, 32]            Swiss Air  Brussels
#
#          To
# 0     paris
# 1     miLAN
# 2  StockOlm
# 3     PaRis
# 4    londOn

# %%
##3
temp_df.From = temp_df['From'].str.capitalize()
temp_df.To = temp_df['To'].str.capitalize()
temp_df.From_To = temp_df['From_To'].str.capitalize()

# %%
temp_df
# Out:
#            From_To  FlightNumber  RecentDelays              Airline      From  \
# 0     London_paris         10045      [23, 47]               KLM(!)    London
# 1     Madrid_milan         10055            []    <Air France> (12)    Madrid
# 2  London_stockolm         10065  [24, 43, 87]  (British Airways. )    London
# 3   Budapest_paris         10075          [13]       12. Air France  Budapest
# 4  Brussels_london         10085      [67, 32]            Swiss Air  Brussels
#
#          To
# 0     Paris
# 1     Milan
# 2  Stockolm
# 3     Paris
# 4    London

# %%
##4
df.drop(df.columns[0],axis=1)
# Out:
#    FlightNumber  RecentDelays              Airline
# 0         10045      [23, 47]               KLM(!)
# 1         10055            []    <Air France> (12)
# 2         10065  [24, 43, 87]  (British Airways. )
# 3         10075          [13]       12. Air France
# 4         10085      [67, 32]            Swiss Air

# %%
df['From_To'] = temp_df['From_To']
df
# Out:
#            From_To  FlightNumber  RecentDelays              Airline
# 0     London_paris         10045      [23, 47]               KLM(!)
# 1     Madrid_milan         10055            []    <Air France> (12)
# 2  London_stockolm         10065  [24, 43, 87]  (British Airways. )
# 3   Budapest_paris         10075          [13]       12. Air France
# 4  Brussels_london         10085      [67, 32]            Swiss Air

# %%
##5
df3 = df['RecentDelays'].apply(pd.Series)
col_dict = {0:'Delay1',1:'Delay2',2:'Delay3'}
df3.rename(columns=col_dict,inplace=True)
df3
# Out:
#    Delay1  Delay2  Delay3
# 0    23.0    47.0     NaN
# 1     NaN     NaN     NaN
# 2    24.0    43.0    87.0
# 3    13.0     NaN     NaN
# 4    67.0    32.0     NaN

# %%
df.replace(to_replace="RecentDelays",value="df3")
# Out:
#            From_To  FlightNumber  RecentDelays              Airline  Delay1  \
# 0     London_paris         10045      [23, 47]               KLM(!)    23.0
# 1     Madrid_milan         10055            []    <Air France> (12)     NaN
# 2  London_stockolm         10065  [24, 43, 87]  (British Airways. )    24.0
# 3   Budapest_paris         10075          [13]       12. Air France    13.0
# 4  Brussels_london         10085      [67, 32]            Swiss Air    67.0
#
#    Delay2  Delay3
# 0    47.0     NaN
# 1     NaN     NaN
# 2    43.0    87.0
# 3     NaN     NaN
# 4    32.0     NaN

# %%
df.drop(df.columns[2],axis=1)
# Out:
#            From_To  FlightNumber              Airline  Delay1  Delay2  Delay3
# 0     London_paris         10045               KLM(!)    23.0    47.0     NaN
# 1     Madrid_milan         10055    <Air France> (12)     NaN     NaN     NaN
# 2  London_stockolm         10065  (British Airways. )    24.0    43.0    87.0
# 3   Budapest_paris         10075       12. Air France    13.0     NaN     NaN
# 4  Brussels_london         10085            Swiss Air    67.0    32.0     NaN
